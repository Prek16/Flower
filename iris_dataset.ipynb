# %%
from sklearn.datasets import load_iris

# %%
i=load_iris()

# %%
dir(i)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
print(i.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
i.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
i.frame

# %%
i.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import pandas as pd

# %%
df=pd.DataFrame(i.data,columns=i.feature_names)
df["species"]=i.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %% [markdown]
# #Splitting the data into categories

# %%
s=df.groupby("species")

# %%
setosa=s.get_group(0)
versi=s.get_group(1)
vergi=s.get_group(2)

# %%
setosa.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
versi.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     species
# 50        1
# 51        1
# 52        1
# 53        1
# 54        1

# %%
vergi.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      species
# 100        2
# 101        2
# 102        2
# 103        2
# 104        2

# %% [markdown]
# #Data Visualization for checking hidden pattern of data

# %%
setosa.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
import matplotlib.pyplot as plt

# %%
plt.title("iris dataset visualization")
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.scatter(setosa["petal length (cm)"],setosa["petal width (cm)"],color="purple",label="setosa")
plt.scatter(versi["petal length (cm)"],versi["petal width (cm)"],color="yellow",label="verci")
plt.scatter(vergi["petal length (cm)"],vergi["petal width (cm)"],color="blue",label="vergi")
plt.legend()

# %%
plt.title("iris dataset visualization")
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.scatter(setosa["sepal length (cm)"],setosa["sepal width (cm)"],color="purple",label="setosa")
plt.scatter(versi["sepal length (cm)"],versi["sepal width (cm)"],color="yellow",label="verci")
plt.scatter(vergi["sepal length (cm)"],vergi["sepal width (cm)"],color="blue",label="vergi")
plt.legend()

# %% [markdown]
# #Splitting the data into dependant and indi vars

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
x=df.drop("species",axis=1)

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y=df.species

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
len(train_x),len(test_x)
# Out:
# (120, 30)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model= KNeighborsClassifier()

# %%
model.fit(train_x,train_y)
# Out:
# KNeighborsClassifier()

# %%
model.predict([[2.3,6.1,5.6,2.3]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.score(test_x,test_y)
# Out:
# 1.0

# %%
import numpy as np

# %%
np.sqrt(150)
# Out:
# 12.24744871391589

# %%
for i in range(1,50):
  model= KNeighborsClassifier(n_neighbors=i)
  model.fit(train_x,train_y)
  print("value of i is{}".format(i),model.score(test_x,test_y))
# Out:
# value of i is1 0.9666666666666667
# value of i is2 0.9666666666666667
# value of i is3 0.9666666666666667
# value of i is4 0.9666666666666667
# value of i is5 1.0
# value of i is6 0.9666666666666667
# value of i is7 0.9666666666666667
# value of i is8 0.9666666666666667
# value of i is9 1.0
# value of i is10 0.9666666666666667
# value of i is11 0.9666666666666667
# value of i is12 0.9666666666666667
# value of i is13 1.0
# value of i is14 1.0
# value of i is15 1.0
# value of i is16 1.0
# value of i is17 1.0
# value of i is18 1.0
# value of i is19 1.0
# value of i is20 1.0
# value of i is21 1.0
# value of i is22 1.0
# value of i is23 1.0
# value of i is24 1.0
# value of i is25 1.0
# value of i is26 1.0
# value of i is27 1.0
# value of i is28 1.0
# value of i is29 1.0
# value of i is30 1.0
# value of i is31 1.0
# value of i is32 0.9666666666666667
# value of i is33 1.0
# value of i is34 0.9666666666666667
# value of i is35 1.0
# value of i is36 0.9666666666666667
# ...

# %%
a1=float(input("Enter petal length: "))
a2=float(input("Enter petal width: "))
a3=float(input("Enter sepal length: "))
a4=float(input("Enter sepal width: "))
print(model.predict([[a1,a2,a3,a4]]))
# Out:
# Enter petal length: 1.5
# Enter petal width: 2.11
# Enter sepal length: 6.3
# Enter sepal width: 2.5
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
if model.predict([[a1,a2,a3,a4]])==[0]:
  print("Setosa")
elif model.predict([[a1,a2,a3,a4]])==[1]:
  print("Versicolor")
else:
  print("Verginica")
# Out:
# Versicolor
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
